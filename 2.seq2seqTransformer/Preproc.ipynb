# %%
from datasets import load_dataset
from preprocessing import Aggregate,create_dictionary
import os
dataset = load_dataset("indonlp/NusaX-MT")
pth = "dataset"
l_1="min"
l_2="eng"
agg = Aggregate(pth,dataset)
saved_folder = agg(l_1,l_2)
create_dictionary(source_lang=l_1, target_lang=l_2,data_path=pth)
# Out:
# (<preprocessing.dict.Dictionary at 0x7c2b7c3d7a60>,
# ...
#  ['nikmati cicilan sampai bulan untuak pamasanan tiket pisawat air asia jo kartu kredit bni !',
#   'kue kue nan disajian mambuek awak takana masa lalu . sadolahnyo mode kue jaman dulu antah itu dari penampilan maupun raso . kuenyo lamak dan haragonyo murah lo .',
#   'ibu pernah bakarajo di grab indonesia',
#   'palayanan bus damri sangaik elok',
#   'nio buek postingan yang isionyo maedukasi customers gojek .',
#   'ratuihan rumah di medan tarandam banjir',
#   'barangnyo lumayan cuma yang den heran xiomi redmi note ko tombol onnyo memang agak rusak ? tu baterai memang capek low bat juragan ?',
#   'payah bana mampacayoi urang nan alah pernah bakianat',
#   'lokasi di gombel jo pamandangan semarang tibolah malam dek lampu kota akan tacaliak makanan lamak steak jo teh hangek menu wajib di siko ambiak spot di lua dek udaro dingin dan sajuak',
# ...
