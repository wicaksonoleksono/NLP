# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
from dataloader import get_dataloaders_subword
import nltk
from transformer import Transformer,TransformerEncoder,TransformerDecoder
import utils
from utils_subword import load_sentencepiece_model,sp_detokenize_with_specials

import pickle
from tabulate import tabulate
import utils_subword
nltk.download('punkt')  
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/wicaksonolxn/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
BATCH_SIZE = 64# butuh lebih banyak update 
DATA_PATH = "dataset/"  
DATA_PATH_SPM = "dataset/spm_files"  
SAVE_DIR = "saved"
SRC_VOCAB_SIZE = 5000     
TGT_VOCAB_SIZE = 5000     
N_LAYERS = 1             
N_HEADS = 1
D_MODEL =  128
FFN_HIDDEN = D_MODEL * 4
DROPOUT = 0.5

sp = load_sentencepiece_model(DATA_PATH_SPM, model_prefix="spm_model")
train_loader, val_loader, test_loader = get_dataloaders_subword(
    sp=sp,
    data_path=DATA_PATH, 
    source_lang="min", 
    target_lang="eng", 
    batch_size=BATCH_SIZE, 
    device=device
)

encoder = TransformerEncoder(SRC_VOCAB_SIZE,D_MODEL,N_LAYERS,N_HEADS,FFN_HIDDEN,DROPOUT,device)
decoder = TransformerDecoder(TGT_VOCAB_SIZE,D_MODEL,N_LAYERS,N_HEADS,FFN_HIDDEN,DROPOUT,device)
best_model = Transformer(encoder,decoder,device,utils.PAD_TOKEN).to(device)
best_model.load_state_dict(torch.load(os.path.join(SAVE_DIR, "best_sp.pt")))
criterion = nn.CrossEntropyLoss(ignore_index=utils.PAD_TOKEN) 
print("Model initialized on:", device)
print("Loaded best model for testing!")
# Out:
# SentencePiece model loaded from dataset/spm_files/spm_model.model
# TrainData - Max 'min' sentence length: 76
# TrainData - Max 'eng' sentence length: 107
# TestData - Max 'min' sentence length: 61
# TestData - Max 'eng' sentence length: 75
# ValidData - Max 'min' sentence length: 62
# ValidData - Max 'eng' sentence length: 81
# Number of examples in train_dataset: 799
# Number of examples in valid_dataset: 100
# Number of examples in test_dataset: 100
# Model initialized on: cuda
# Loaded best model for testing!

# %%
import os
import torch
import pickle
import utils
def evaluate_test(model, test_dataset, sp, device, criterion):
    model.eval()
    total_loss = 0.0
    all_bleu   = []
    with torch.no_grad():
        for i in range(len(test_dataset)):
            sample = test_dataset[i]
            src_token_ids = sample["src"]
            tgt_token_ids = sample["tgt"]
            # If tokens are tensors, convert them to lists.
            if torch.is_tensor(src_token_ids):
                src_token_ids = src_token_ids.tolist()
            if torch.is_tensor(tgt_token_ids):
                tgt_token_ids = tgt_token_ids.tolist()
                
            src_tensor = torch.LongTensor(src_token_ids).unsqueeze(0).to(device)
            tgt_tensor = torch.LongTensor(tgt_token_ids).unsqueeze(0).to(device)
            
            # Forward pass through the model (teacher forcing for target input).
            output, _ = model(src_tensor, tgt_tensor[:, :-1])  # shape: [1, seq_len-1, vocab_size]
            vocab_size = output.shape[-1]
            output_2d = output.view(-1, vocab_size)              # [seq_len-1, vocab_size]
            tgt_2d    = tgt_tensor[:, 1:].contiguous().view(-1)    # [seq_len-1]
            loss = criterion(output_2d, tgt_2d)
            total_loss += loss.item()
            
            # Use SentencePiece detokenization to get human-readable sentences.
            ref_text = sp_detokenize_with_specials(sp, tgt_token_ids)
            pred_ids = output[0].argmax(dim=1).tolist()            # [seq_len-1]
            hyp_text = sp_detokenize_with_specials(sp, pred_ids)
            
            bleu_score = utils.get_bleu(hyp_text.split(), ref_text.split())
            all_bleu.append(bleu_score)
            
    avg_loss = total_loss / len(test_dataset)
    avg_bleu = sum(all_bleu) / len(all_bleu)
    return avg_loss, avg_bleu

# Example usage:
test_loss, test_bleu = evaluate_test(best_model, test_loader, sp, device, criterion)
print(f"Test Loss = {test_loss:.4f} | BLEU = {test_bleu:.2f}")
# Out:
# Test Loss = 3.7347 | BLEU = 2.93

# %%
import os
import pickle
import torch
from translation import translate_sentence_piece  
num_samples_to_translate = 20
for i in range(num_samples_to_translate):
    sample = test_loader[i]  
    src_token_ids = sample["src"]
    tgt_token_ids = sample["tgt"]
    
    if torch.is_tensor(src_token_ids):
        src_token_ids = src_token_ids.tolist()
    if torch.is_tensor(tgt_token_ids):
        tgt_token_ids = tgt_token_ids.tolist()
    
    src_text = sp_detokenize_with_specials(sp, src_token_ids)
    real_target_text = sp_detokenize_with_specials(sp, tgt_token_ids)
    
    predicted_translation, predicted_tokens = translate_sentence_piece(
        token_ids=src_token_ids,
        sp=sp,
        model=best_model,
        device=device,
        max_len=utils.MAX_SENT_LEN,
    )
    
    print("_________________________________________________")
    print(f"|                 SRC NO.{i+1}                  |")
    print("_________________________________________________")
    print(f"Source: {src_text}")
    print(f"Predicted Token : {predicted_tokens}")
    print(f"Predicted Translation: {predicted_translation}")
    print(f"Real Target: {real_target_text}\n")
    print("_______________________________________________")
# Out:
# _________________________________________________
# |                 SRC NO.1                  |
# _________________________________________________
# Source: awak manyasa manggunoan jaso lion air
# Predicted Token : [1, 160, 158, 17, 22, 120, 4993, 38, 655, 34, 219, 15, 4981, 688, 106, 4977, 91, 4987, 910, 2080, 2485, 27, 20, 1597, 1030, 4984, 1106, 4998, 225, 4982, 43, 119, 4983, 888, 4989, 4994, 8, 67, 4996, 319, 4986, 195, 57, 4979, 2400, 2]
# Predicted Translation: i was nothen thated tointing use the food is a like its of you commently doncept forkage
# Real Target: im never using lion air services ever again
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.2                  |
# _________________________________________________
# Source: banyak hal nan dapek kito lakukan untuak maiisi wakatu luang
# Predicted Token : [1, 910, 2080, 2485, 22, 120, 1106, 4998, 225, 4982, 43, 119, 4983, 888, 4984, 4987, 158, 17, 27, 20, 1597, 655, 34, 219, 15, 4981, 1357, 4993, 47, 4994, 4977, 91, 106, 195, 57, 4979, 2400, 1136, 5, 506, 1376, 16, 1577, 35, 525, 60, 63, 392, 1116, 4989, 758, 4978, 1870, 2499, 4985, 75, 1572, 879, 354, 160, 858, 1030, 1259, 4986, 71, 111, 507, 121, 4936, 1926, 167, 2576, 1141, 305, 759, 622, 228, 1579, 4988, 123, 652, 1585, 2906, 84, 409, 159, 4996, 319, 4991, 38, 1103, 4980, 1229, 2476, 56, 1611, 93, 23, 2388, 477, 543, 4999, 886, 2498, 2]
# Predicted Translation: the food is not of you commentse was a like thated toughery using forkage and moreveryone haves in bandung onlownackadaidaybech as i order it just getterest java election but also gooducriblease checkelicioceppenjoive beautifulinks arrivailable
# Real Target: there are many things we can do in our spare time
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.3                  |
# _________________________________________________
# Source: samakin apatis malaporan hal hal macam ko  soalnyo sampai minggu patang masih tetap alun dikarajoan  cuma janji janji taruih
# Predicted Token : [1, 160, 158, 17, 22, 120, 4993, 38, 655, 50, 771, 131, 4987, 4977, 91, 106, 15, 4981, 688, 219, 11, 4994, 43, 119, 4983, 888, 4984, 1106, 4998, 910, 404, 3753, 2]
# Predicted Translation: i was nothen this place using tointed by comments of the samarinda
# Real Target: gettin more apathetic each time i report stuff like this  cu even after last week they still havent worked on it  empty promises after empty promises
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.4                  |
# _________________________________________________
# Source: harago salangik porsi saketek indak janji ka tibo baliak do untuak nan kaduo kali  masakannyo indak beda jauah samo ema wak pastinyo
# Predicted Token : [1, 160, 4998, 910, 2080, 158, 17, 22, 120, 4993, 47, 4987, 4977, 91, 106, 15, 4981, 1357, 137, 4980, 4999, 219, 63, 1578, 655, 50, 771, 131, 325, 1899, 195, 57, 4986, 4994, 43, 119, 4983, 234, 4984, 1106, 54, 2847, 4867, 67, 4996, 319, 4991, 38, 1103, 4978, 758, 4985, 75, 1572, 27, 20, 1597, 1030, 35, 525, 60, 477, 543, 4990, 1924, 13, 4989, 2476, 56, 1611, 93, 23, 2388, 1136, 5, 506, 1376, 16, 1577, 2485, 1259, 507, 121, 4936, 1926, 167, 2576, 1141, 231, 86, 2527, 2]
# Predicted Translation: if the food was nothere using tougitived into this plactions forty commends our trip advisoronceppenjonowdaybe a like it haves arrig deall beautifulinks and moreveryone is justerest java election but stilding
# Real Target: price off the roof for an eenie meenie portion i cant promise coming back a second time  cookings not even that different from my mas
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.5                  |
# _________________________________________________
# Source: indak mangarati yo baa kok resto ko manduduki paringkek dari an resto nan ado di jakarta harago maha  lokasi tasambunyi dan raso makanan biaso se  jan lah terlalu picayo jo review nan manyasekkan
# Predicted Token : [1, 910, 2080, 158, 137, 4993, 47, 4987, 2485, 22, 120, 1106, 4998, 225, 4982, 43, 119, 4983, 234, 4984, 4977, 91, 106, 195, 57, 27, 20, 1597, 655, 50, 771, 131, 325, 1899, 2]
# Predicted Translation: the food withere is not of you commends using for a like this plactions
# Real Target: i dont get why this restaurant is ranked th out of ish restaurants in jakarta  so epensive  the location is hidden and the food is so so  dont blindly trust misleading reviews
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.6                  |
# _________________________________________________
# Source: akses manuju dusun bambu bisa ditampuah kiro kiro dalam wakatu jam manggunoan oto pribadi  bakunjuang ka dusun bambu diusahoan pas sanjo karano awak dapek maliek jaleh pamandangan nan ado dan waktu yang pas untuak makan malam
# Predicted Token : [1, 160, 158, 17, 27, 20, 1597, 910, 2080, 2485, 305, 759, 22, 120, 1106, 4998, 225, 4982, 43, 1023, 35, 525, 4987, 4977, 91, 106, 15, 4981, 1357, 4993, 4986, 4994, 195, 57, 4985, 75, 4984, 1136, 5, 506, 1376, 16, 1577, 655, 34, 219, 63, 392, 1116, 4989, 758, 4978, 47, 888, 2169, 1030, 1259, 507, 121, 4936, 1647, 3042, 703, 790, 60, 477, 543, 234, 12, 4921, 1266, 4996, 4979, 2400, 2270, 38, 1103, 4980, 4999, 886, 2498, 2]
# Predicted Translation: i was a like the food is also not of you came have using toughty fordays and moreveryone thated in bandung onlownerent level it justerest java aka gedung sate kambes arriendarving prockage cirebonenjoivailable
# Real Target: the road to dusun bambu can be travelled in around hours by a private car  try visiting dusun bambu around dusk because its when we can clearly see the scenery and just in time for dinner
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.7                  |
# _________________________________________________
# Source: awak baru se basobok kawan wak nan bakarajo di trans tv
# Predicted Token : [1, 160, 158, 17, 27, 20, 1597, 910, 4994, 4977, 91, 4987, 655, 34, 219, 15, 4981, 688, 106, 63, 5, 506, 1376, 16, 1577, 195, 543, 234, 4984, 1106, 4998, 225, 4982, 43, 67, 4996, 4979, 2400, 2]
# Predicted Translation: i was a like they use thated tointing in moreveryone friends of you conckage
# Real Target: i just met my friend who works at trans tv
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.8                  |
# _________________________________________________
# Source: makanannyo agak lamo tapi suasana nan diagiah keren dan unik jadi sambia manunggu makanan bisa manikmati suasana di resto ko menu dan disajian baragam dan lamak
# Predicted Token : [1, 910, 2080, 2485, 305, 759, 35, 525, 4987, 158, 17, 27, 20, 120, 4984, 4977, 1874, 60, 15, 4981, 54, 195, 57, 4986, 4994, 43, 1023, 1136, 1030, 534, 325, 1899, 1106, 4998, 167, 119, 4983, 234, 219, 598, 3565, 655, 50, 771, 131, 4993, 47, 888, 4988, 1234, 106, 63, 392, 1116, 4989, 758, 4978, 1870, 4991, 38, 1103, 4980, 84, 409, 159, 91, 4982, 137, 2498, 148, 225, 124, 2392, 1928, 2431, 4037, 354, 160, 858, 453, 2470, 11, 111, 507, 121, 4936, 1647, 3042, 4985, 75, 1572, 879, 1141, 231, 86, 2527, 29, 436, 1904, 3514, 1629, 604, 2383, 5, 506, 603, 166, 2]
# Predicted Translation: the food is also have was a lots amaes tour forty came and it tastions ofecommended chicken this placherentrimping in bandung onlownackpenjoieliciousuitable menu youngry juice view as i order sound betterest java aka gedungdaybech but stilding regret eatalia sauce more romant
# Real Target: service may take a bit long but the atmosphere is cool and uniue so we can enjoy ith while waiting for the food  the menu is varied and delicious
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.9                  |
# _________________________________________________
# Source: makanan di siko lamak lamak dengan banyak variasi  sadolahnyo lamak jo pamandangan rancak  pelayanan nan maksimal dari uni diah dan gina dari awal datang sampai salasai dilayani dengan sangaik elok
# Predicted Token : [1, 910, 2080, 2485, 305, 759, 22, 120, 1106, 4998, 167, 4986, 4994, 4977, 1874, 4984, 4987, 158, 137, 4993, 47, 888, 15, 4981, 1357, 86, 4989, 525, 60, 1136, 195, 4988, 119, 4983, 234, 219, 598, 3565, 43, 1604, 35, 17, 27, 20, 1597, 655, 34, 1030, 534, 325, 1899, 1141, 160, 858, 106, 822, 4006, 2248, 282, 2431, 4037, 354, 4979, 2400, 2270, 2603, 300, 4991, 38, 1103, 111, 507, 121, 4936, 1647, 3042, 4985, 2498, 148, 477, 543, 4999, 886, 453, 2470, 63, 392, 1116, 1151, 1618, 4990, 4978, 1870, 2499, 734, 377, 4992, 13, 771, 131, 2576, 7, 30, 2403, 409, 159, 91, 4982]
# Predicted Translation: the food is also not ofecty amase witherent tougillaves and frommended chicken come has a like that it tastions but i ordering spicy sambal price view askage cirebon atmospenjoetterest java aka gedungdable menu arrivail sound in bandung on top nignackadai strawbal plaction stufficiousu
# Real Target: the food here is delicious with many varieties  everything is delicious with good scenery  maimum service from miss diah and miss gina from start to finish  very well served
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.10                  |
# _________________________________________________
# Source: cukuik mudah mancari lokasi ko tingga maikuikan se arah ka tangah kota  bekoh di kiri jalan nampak parkiran oto nan cukuik banyak disitulah tampek kafe ko  rasonyo kafe ko memang jarang langang banyak bana pangunjuang
# Predicted Token : [1, 910, 2080, 2485, 305, 759, 22, 120, 4993, 47, 4987, 158, 137, 4986, 4994, 4977, 38, 1103, 4978, 758, 4985, 2498, 1136, 1030, 4984, 1106, 4998, 225, 4982, 43, 119, 4983, 234, 219, 15, 4981, 1357, 86, 4989, 525, 60, 477, 543, 4990, 121, 1110, 195, 57, 27, 20, 1597, 655, 50, 771, 131, 325, 1899, 2]
# Predicted Translation: the food is also nothere witty enjonowdable and its of you commended tougillaves arrigestern for a like this plactions
# Real Target: pretty easy to locate this place just gotta follow the directions from the city centre  later you should spot a pretty crowded parking space on your left side thats where this cafe is  seems like the cafes rarely empt
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.11                  |
# _________________________________________________
# Source: kecewa awak samo provider ko sampai kesal berang emosi awak kalua dek karano sinyal nan indak batua
# Predicted Token : [1, 160, 158, 17, 22, 120, 4993, 38, 655, 50, 771, 131, 4987, 4977, 91, 106, 15, 4981, 1357, 4978, 47, 4994, 5, 506, 1376, 16, 1577, 35, 525, 60, 4984, 1106, 4998, 910, 109, 884, 1269, 219, 11, 2396, 710, 175, 195, 57, 4979, 2400, 2]
# Predicted Translation: i was nothen this place using tougnery moreveryone havess of theirst timed buy tiket kami forkage
# Real Target: im so disappointed with this provider to the point where im frustrated angry and mad  i even need to step outside because the signal is just that bad
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.12                  |
# _________________________________________________
# Source: bali kaus topi atau jam tangan di kadai monoton roomstore bisa diago khusus pakai aplikasi di hape bosku
# Predicted Token : [1, 910, 404, 4987, 158, 137, 4993, 38, 1103, 4994, 4977, 91, 106, 63, 1578, 27, 20, 1597, 655, 34, 219, 15, 4981, 1357, 86, 4989, 525, 60, 4984, 1106, 4998, 225, 4982, 43, 12, 4985, 75, 1572, 195, 57, 4986, 2476, 56, 1611, 93, 23, 2388, 477, 543, 234, 2696, 4084, 627, 7, 1604, 1137, 4979, 2400, 2]
# Predicted Translation: the same withenjoy using into a like thated tougillavess of you cardaybe fort beautifulinks arriendation sudah bag some backage
# Real Target: buy shirts hats or watches in lapak monoton roomstore price negotiable for phone app users my dudes
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.13                  |
# _________________________________________________
# Source: untuak malam minggu di sinan diagiah tampek nan indak nyaman karano pas urang lewat di sinan tampek kami goyang goyang labiah tapeknyo mirip macam kadai pinggia jalan  indak sasuai jo harago makanan nan disajian saharusnyo pasangan diagiah pulo tampek nan rancak bukan sumbarang tarimo tamu dan latak di tampek macam itu
# Predicted Token : [1, 910, 2080, 2485, 305, 759, 35, 525, 4987, 158, 17, 27, 20, 120, 4984, 4977, 38, 1103, 4994, 195, 57, 4986, 2498, 1136, 1030, 43, 119, 4998, 167, 325, 1899, 1106, 54, 106, 15, 4981, 1357, 4993, 47, 888, 655, 34, 219, 63, 392, 1116, 4989, 758, 4978, 1870, 2499, 4985, 75, 1572, 879, 354, 4979, 2400, 2270, 2603, 300, 4991, 761, 1593, 60, 477, 543, 234, 12, 797, 21, 2403, 409, 159, 91, 230, 1576, 4988, 123, 652, 1585, 2906, 84, 4980, 4999, 886, 453, 2470, 771, 131, 2576, 1141, 160, 858, 225, 4982, 137, 7, 1604, 1137, 67, 4996, 319, 1033, 2479, 1386, 3228, 2]
# Predicted Translation: the food is also have was a lots enjoy fortable and it comfections ouring tougherent thated in bandung onlownackadaidaybech askage cirebon atmosperiences arriendar namun difficiousandidriblease checkelivail sound plaction but i order youit some baconcephone credit voucher
# Real Target: on saturday night there couples are given uncomfortabe seats since itll always shake whenever people pass by feels more like a roadside stall  the food is not worth the price at all couples should be given a
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.14                  |
# _________________________________________________
# Source: bagian sabanyak banyaknyo  bia urang ko diproses  taragak mancaliak video minta maaf sambia nangih nangih dah tu mangadu ka amak tu ngecek kalau parlakuan itu indak sangajo
# Predicted Token : [1, 160, 4998, 910, 4994, 4977, 91, 230, 4984, 4987, 331, 652, 1585, 195, 57, 27, 20, 1597, 655, 50, 3396, 158, 17, 22, 120, 4993, 38, 1103, 506, 1376, 16, 1577, 15, 4981, 688, 106, 63, 1578, 5, 1607, 1106, 54, 2847, 4867, 67, 4996, 4979, 219, 11, 2396, 710, 175, 43, 119, 4983, 234, 4989, 525, 60, 477, 543, 4999, 886, 2498, 1136, 1030, 35, 47, 888, 2169, 225, 4982, 13, 1269, 4986, 2476, 56, 1611, 93, 4985, 75, 1572, 879, 354, 2618, 2475, 84, 409, 159, 255, 2459, 2485, 305, 759, 622, 228, 1141, 231, 86, 2527, 2]
# Predicted Translation: if they usandseoplease for a like this restaurant was nothenjooreveryone tointing into most our trip advisoroncked buy tiket kami commendlaves arrivailable and it herent level youal timt beautifuldaybech as far awelicioupset is also good but stilding
# Real Target: share this as much as you can  lets see him get arrested  been a long time since i see someone apologiing while crying their eyes out and begging to their moms saying that it was just an accident
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.15                  |
# _________________________________________________
# Source: untuak daerah banda aceh dan sekitarnyo masih lancar ndak ado gangguan samo sakali
# Predicted Token : [1, 910, 195, 57, 27, 20, 1597, 655, 50, 771, 131, 4987, 158, 17, 22, 120, 4984, 4977, 91, 106, 15, 4981, 1357, 4993, 47, 4994, 43, 119, 4983, 888, 4989, 525, 60, 63, 392, 1136, 1030, 35, 758, 4978, 1870, 2499, 219, 11, 2396, 710, 175, 2485, 305, 759, 622, 228, 1579, 4986, 2476, 38, 160, 4998, 225, 4982, 71, 111, 507, 121, 4936, 1926, 167, 2576, 1141, 231, 86, 2527, 2]
# Predicted Translation: the for a like this place was nots using toughery commentlaves in bandung and it hownackadaied buy tiket kami is also gooduct been if you getterest java election but stilding
# Real Target: things seem to be going smoothly for the banda aceh region and its vicinities no issues whatsoever
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.16                  |
# _________________________________________________
# Source: emosi jo gojek yang taruih salah jalan kalau nio ka rumah awak
# Predicted Token : [1, 160, 4998, 910, 5, 4994, 4977, 91, 106, 158, 17, 22, 120, 4993, 38, 655, 50, 3396, 4984, 4987, 15, 4981, 688, 219, 11, 2396, 710, 175, 195, 57, 27, 20, 1597, 1030, 35, 525, 60, 63, 1578, 43, 119, 4983, 888, 4989, 758, 4978, 47, 71, 111, 507, 121, 4936, 1926, 167, 4986, 2476, 56, 1611, 93, 4985, 75, 1572, 885, 1376, 16, 1577, 14, 652, 1585, 2906, 84, 409, 159, 4996, 319, 946, 67, 757, 3514, 1629, 2485, 305, 759, 622, 228, 1579, 4979, 2400, 1106, 54, 2847, 4867, 29, 112, 2041, 1136, 1230, 1592, 354, 225, 4982, 570, 477, 543, 234, 4157, 1889, 4988]
# Predicted Translation: if the my using was nothen this restaurantse tointed buy tiket kami for a like it haves into commentlowner getterest java elect beautifuldaybe everyone please checkelicioceplionna eatalia is also gooduckage our trip advisor remember and yell as youota arriend workshopr
# Real Target: so cranky with gojek drivers who always get lost when theyre trying to come to my house
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.17                  |
# _________________________________________________
# Source: makan kaki kambiang paho nan ampuak jo lumayan gadang untuak nan medium pas untuak ciek urang makan ndak pakai nasi samo es lemon tea  segar kurangnyo cuma tampek barasok wajar se namonyo kambiang baka hehehe
# Predicted Token : [1, 910, 771, 131, 4987, 158, 17, 27, 20, 1597, 655, 34, 219, 15, 4981, 1357, 4993, 38, 1103, 4994, 4977, 91, 106, 195, 57, 4986, 4984, 1106, 4998, 225, 4982, 43, 119, 4983, 234, 4989, 525, 60, 63, 392, 1136, 5, 506, 1376, 16, 1577, 35, 47, 888, 2169, 160, 858, 2485, 305, 759, 22, 120, 143, 23, 2388, 477, 543, 4999, 886, 2498, 2]
# Predicted Translation: the place was a like thated toughenjoy using forts of you commendlaves in bandung and moreveryone herent level i order is also nottainks arrivailable
# Real Target: i had goat leg it was tender and uite big for medium sie  perfect for one person with no rice coupled with iced lemon tea  pretty fresh but the place reeked of smoke  i guess its epected its roasted goat after all hehehe
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.18                  |
# _________________________________________________
# Source: minuman apo sih kok caro minumnyo aneh rasonyo aneh lo lai tu
# Predicted Token : [1, 910, 2080, 2485, 22, 120, 4993, 47, 4987, 158, 17, 27, 20, 1597, 655, 34, 219, 15, 4981, 1357, 137, 4980, 727, 1926, 167, 4986, 4994, 4977, 91, 230, 4984, 1106, 4998, 225, 4982, 43, 119, 4983, 234, 4989, 525, 60, 63, 1578, 5, 506, 1376, 16, 1577, 195, 57, 4985, 75, 1572, 106, 822, 4006, 1136, 1030, 35, 758, 4978, 1870, 2499, 2]
# Predicted Translation: the food is nothere was a like thated tougitional electy usands of you commendlaves into moreveryone fordaybeing spicy and it hownackadai
# Real Target: what kind of drink has such a weird way of drinking  tastes just as weird too
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.19                  |
# _________________________________________________
# Source: adiak wak sadang manonton harry potter di trans tv
# Predicted Token : [1, 160, 4998, 910, 4994, 4977, 91, 4987, 158, 137, 4993, 38, 655, 34, 219, 15, 4981, 1357, 67, 4996, 4979, 106, 63, 1578, 27, 20, 1597, 1030, 4984, 1106, 54, 195, 57, 4985, 75, 1572, 879, 354, 225, 4982, 43, 119, 4983, 888, 4989, 525, 60, 477, 543, 234, 2]
# Predicted Translation: if they use withen thated tougoncking into a like its our fordaybech as you commentlaves arriend
# Real Target: my brother is watching harry potter on trans tv
#
# _______________________________________________
# _________________________________________________
# |                 SRC NO.20                  |
# _________________________________________________
# Source: menu di tampek ko sabatuanyo sadarhana bana tapi pamiliaknyo kreatif  sajian mie rotidan makanan panutuiknyo di mi samo bamacam piliahan  tampek sero untuak bakumpua jo kawan kawan  untuak haragonyo ndak talalu maha sasuai samo rasonyo
# Predicted Token : [1, 910, 2080, 2485, 305, 759, 35, 525, 4987, 158, 137, 4993, 47, 4994, 4977, 38, 1103, 4978, 758, 4985, 2498, 1136, 1030, 4984, 1106, 4998, 225, 4982, 43, 119, 4983, 234, 219, 15, 4981, 54, 195, 543, 60, 477, 2570, 13, 4989, 106, 822, 120, 143, 23, 2388, 20, 1597, 655, 50, 771, 131, 325, 1899, 2]
# Predicted Translation: the food is also have withery enjonowdable and its of you commended tour fries arrangalling spottainks like this plactions
# Real Target: this menu here is honestly really simple but the owner is creative  the noodles bread and desserts can be mied and matched from a variety of options  the venue is also fun to hang out with friends  the price isnt that epensive it just fits
#
# _______________________________________________
